# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %%
vector=torch.tensor([7,7])
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
matrix=torch.tensor([[1,2]])

# %%
matrix.ndim
# Out:
# 2

# %%
matrix.shape
# Out:
# torch.Size([1, 2])

# %%
matrix[0]
# Out:
# tensor([1, 2])

# %%
tensor=torch.tensor([[[1,2]
                      ,[2,3]]])
tensor
# Out:
# tensor([[[1, 2],
#          [2, 3]]])

# %%
tensor.ndim
# Out:
# 3

# %%
tensor.shape
# Out:
# torch.Size([1, 2, 2])

# %%
randomtensor=torch.rand(3,4)

# %%
randomimagetensor= torch.rand(224,224)
randomimagetensor.shape,randomimagetensor.ndim
# Out:
# (torch.Size([224, 224]), 2)

# %%
ones= torch.ones(224,3)

# %%
ones.dtype
# Out:
# torch.float32

# %%
mytensor=torch.arange(1,12,2)

# %%
zeros= torch.zeros_like(mytensor)
zeros
# Out:
# tensor([0, 0, 0, 0, 0, 0])

# %%
floattensor=torch.tensor([3],dtype=torch.float16,device='cpu',requires_grad=False)
floattensor.dtype
# Out:
# torch.float16

# %% [markdown]
# 3 main errors you'll run into with pytorch and deep learning:
# 1. tensor dataype
# 2. tensor shape
# 3. tensor not on the right device

# %%
floattensor=floattensor.type(torch.float32)
floattensor
# Out:
# tensor([3.])

# %%
torch.mm(ones,randomtensor)
# Out:
# tensor([[1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
#         [1.4261, 1.7377, 1.7165, 1.5174],
# ...

# %%
randomtensor.T
# Out:
# tensor([[0.3616, 0.5780, 0.4865],
#         [0.3537, 0.3881, 0.9958],
#         [0.5691, 0.4058, 0.7416],
#         [0.3610, 0.4490, 0.7074]])

# %%
randomtensor
# Out:
# tensor([[0.3616, 0.3537, 0.5691, 0.3610],
#         [0.5780, 0.3881, 0.4058, 0.4490],
#         [0.4865, 0.9958, 0.7416, 0.7074]])

# %%
x=torch.tensor([1,2,3,4])
x.shape
# Out:
# torch.Size([4])

# %%
x[3]
# Out:
# tensor(4)

# %%
x=x.reshape(2,2)
x
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
torch.stack([x,x.T])
# Out:
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[1, 3],
#          [2, 4]]])

# %%
x=x.reshape(4,1)
x
# Out:
# tensor([[1],
#         [2],
#         [3],
#         [4]])

# %%
x.permute(1,0)
# Out:
# tensor([[1, 2, 3, 4]])

# %%
x.shape
# Out:
# torch.Size([4, 1])

# %%
array=np.array([1,2,3])
array=torch.from_numpy(array)

# %%
array=array.numpy()
array
# Out:
# array([1, 2, 3])
